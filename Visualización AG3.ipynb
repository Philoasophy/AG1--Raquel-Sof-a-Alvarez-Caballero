# %% [markdown]
# <a href="https://colab.research.google.com/github/Philoasophy/AG1--Raquel-Sof-a-Alvarez-Caballero/blob/master/Visualizaci%C3%B3n%20AG3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import io

# %%
#carga del fichero
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
s=requests.get(url).content
titanic=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null object
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null object
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.3+ KB

# %%
#Renombra la columna class a clase
titanic.rename(columns={'class': 'clase'},   inplace=True)        
titanic.rename(columns={'fare': 'tarifa'},   inplace=True)     
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# tarifa         891 non-null float64
# embarked       889 non-null object
# clase          891 non-null object
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null object
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.3+ KB

# %%
titanic.clase.unique()
# Out:
# array(['Third', 'First', 'Second'], dtype=object)

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
def class_num_func(row):
    Clase={'Third':3,'First':1,'Second':2}
    return Clase[row.clase]
titanic['class_num'] = titanic.apply(class_num_func, axis='columns')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  embark_town  alive  alone class_num
# 0         0       3    male  22.0  ...  Southampton     no  False         3
# 1         1       1  female  38.0  ...    Cherbourg    yes  False         1
# 2         1       3  female  26.0  ...  Southampton    yes   True         3
# 3         1       1  female  35.0  ...  Southampton    yes  False         1
# 4         0       3    male  35.0  ...  Southampton     no   True         3
#
# [5 rows x 16 columns]

# %%
#Consulta con condiciones
titanic[
(titanic.sex == 'female')
& (titanic['clase'].isin(['First', 'Third']))
& (titanic.age > 45 )
& (titanic.survived == 0)
]
# Out:
#      survived  pclass     sex   age  ...  embark_town  alive  alone class_num
# 132         0       3  female  47.0  ...  Southampton     no  False         3
# 177         0       1  female  50.0  ...    Cherbourg     no   True         1
# 736         0       3  female  48.0  ...  Southampton     no  False         3
#
# [3 rows x 16 columns]

# %%
sns.distplot (titanic.age.dropna( ))
sns.plt.show ( )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-8b408c6cf492> in <module>()
#       1 sns.distplot (titanic.age.dropna( ))
# ----> 2 sns.plt.show ( )
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
sns.countplot(x="clase", data=titanic)

# %%
sns.distplot (titanic.age.dropna( ))
sns.plt.show ( )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-8b408c6cf492> in <module>()
#       1 sns.distplot (titanic.age.dropna( ))
# ----> 2 sns.plt.show ( )
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
sns.set(font_scale=1)
g = sns.FacetGrid(titanic, row='survived',col='clase')
g.map(sns.distplot, "age")
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a0de098d32ce> in <module>()
#       2 g = sns.FacetGrid(titanic, row='survived',col='clase')
#       3 g.map(sns.distplot, "age")
# ----> 4 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
#Diagrama de dispersion con Distribucion de cada variable: tarifa(precio)/age(edad)
sns.jointplot(data=titanic, x='age', y='tarifa',
kind='reg', color='b')
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-3de73185d286> in <module>()
#       1 sns.jointplot(data=titanic, x='age', y='tarifa',
#       2 kind='reg', color='b')
# ----> 3 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
# Mapa de calor de correlaciones
tc = titanic.corr()
sns.heatmap(tc,cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
sns.set(style="ticks")
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
